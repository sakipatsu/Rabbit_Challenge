# %% [markdown]
# <a href="https://colab.research.google.com/github/sakipatsu/Rabbit_Challenge/blob/main/2_4_optimizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 準備

# %% [markdown]
# ## Googleドライブのマウント

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## sys.pathの設定

# %% [markdown]
# 以下では，Googleドライブのマイドライブ直下にDNN_codeフォルダを置くことを仮定しています．必要に応じて，パスを変更してください．

# %%
import sys
# sys.path.append('/content/drive/My Drive/DNN_code')
# sys.path.append('/content/drive/My Drive/DNN_code/lesson_2')
sys.path.append('/content/drive/My Drive/StudyAI/Step3')
sys.path.append('/content/drive/My Drive/StudyAI/Step3/lesson2')

# %% [markdown]
# # optimizer

# %% [markdown]
# ## SGD

# %%
import sys, os
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
from collections import OrderedDict
from common import layers
from data.mnist import load_mnist
import matplotlib.pyplot as plt
from multi_layer_net import MultiLayerNet


# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

# batch_normalizationの設定 ================================
use_batchnorm = True
# use_batchnorm = False
# ====================================================


network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='sigmoid', weight_init_std=0.01,
                       use_batchnorm=use_batchnorm)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]
        
        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)
    
    
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))

        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.21
#                 : 10. 正答率(テスト) = 0.2131
# Generation: 20. 正答率(トレーニング) = 0.2
#                 : 20. 正答率(テスト) = 0.2812
# Generation: 30. 正答率(トレーニング) = 0.35
#                 : 30. 正答率(テスト) = 0.3127
# Generation: 40. 正答率(トレーニング) = 0.36
#                 : 40. 正答率(テスト) = 0.3527
# Generation: 50. 正答率(トレーニング) = 0.47
#                 : 50. 正答率(テスト) = 0.395
# Generation: 60. 正答率(トレーニング) = 0.4
#                 : 60. 正答率(テスト) = 0.3767
# Generation: 70. 正答率(トレーニング) = 0.36
#                 : 70. 正答率(テスト) = 0.3474
# Generation: 80. 正答率(トレーニング) = 0.38
#                 : 80. 正答率(テスト) = 0.3748
# Generation: 90. 正答率(トレーニング) = 0.31
#                 : 90. 正答率(テスト) = 0.3607
# Generation: 100. 正答率(トレーニング) = 0.42
#                 : 100. 正答率(テスト) = 0.3605
# Generation: 110. 正答率(トレーニング) = 0.36
#                 : 110. 正答率(テスト) = 0.3807
# Generation: 120. 正答率(トレーニング) = 0.43
#                 : 120. 正答率(テスト) = 0.3789
# Generation: 130. 正答率(トレーニング) = 0.48
#                 : 130. 正答率(テスト) = 0.3808
# Generation: 140. 正答率(トレーニング) = 0.43
#                 : 140. 正答率(テスト) = 0.377
# Generation: 150. 正答率(トレーニング) = 0.43
#                 : 150. 正答率(テスト) = 0.3979
# Generation: 160. 正答率(トレーニング) = 0.43
#                 : 160. 正答率(テスト) = 0.3908
# Generation: 170. 正答率(トレーニング) = 0.38
#                 : 170. 正答率(テスト) = 0.3972
# Generation: 180. 正答率(トレーニング) = 0.44
#                 : 180. 正答率(テスト) = 0.4041
# Generation: 190. 正答率(トレーニング) = 0.5
#                 : 190. 正答率(テスト) = 0.3976
# Generation: 200. 正答率(トレーニング) = 0.4
#                 : 200. 正答率(テスト) = 0.4097
# Generation: 210. 正答率(トレーニング) = 0.46
#                 : 210. 正答率(テスト) = 0.4157
# Generation: 220. 正答率(トレーニング) = 0.38
#                 : 220. 正答率(テスト) = 0.4108
# Generation: 230. 正答率(トレーニング) = 0.45
#                 : 230. 正答率(テスト) = 0.3884
# Generation: 240. 正答率(トレーニング) = 0.4
#                 : 240. 正答率(テスト) = 0.3909
# Generation: 250. 正答率(トレーニング) = 0.29
#                 : 250. 正答率(テスト) = 0.3927
# Generation: 260. 正答率(トレーニング) = 0.34
#                 : 260. 正答率(テスト) = 0.3788
# Generation: 270. 正答率(トレーニング) = 0.43
#                 : 270. 正答率(テスト) = 0.3829
# Generation: 280. 正答率(トレーニング) = 0.45
#                 : 280. 正答率(テスト) = 0.4066
# Generation: 290. 正答率(トレーニング) = 0.36
#                 : 290. 正答率(テスト) = 0.4138
# Generation: 300. 正答率(トレーニング) = 0.45
#                 : 300. 正答率(テスト) = 0.4188
# Generation: 310. 正答率(トレーニング) = 0.39
#                 : 310. 正答率(テスト) = 0.4182
# Generation: 320. 正答率(トレーニング) = 0.49
#                 : 320. 正答率(テスト) = 0.4221
# Generation: 330. 正答率(トレーニング) = 0.37
#                 : 330. 正答率(テスト) = 0.4119
# Generation: 340. 正答率(トレーニング) = 0.47
#                 : 340. 正答率(テスト) = 0.4159
# Generation: 350. 正答率(トレーニング) = 0.42
#                 : 350. 正答率(テスト) = 0.4307
# Generation: 360. 正答率(トレーニング) = 0.48
#                 : 360. 正答率(テスト) = 0.42
# Generation: 370. 正答率(トレーニング) = 0.5
#                 : 370. 正答率(テスト) = 0.4174
# Generation: 380. 正答率(トレーニング) = 0.39
#                 : 380. 正答率(テスト) = 0.4221
# Generation: 390. 正答率(トレーニング) = 0.48
#                 : 390. 正答率(テスト) = 0.4184
# Generation: 400. 正答率(トレーニング) = 0.41
#                 : 400. 正答率(テスト) = 0.4261
# Generation: 410. 正答率(トレーニング) = 0.45
#                 : 410. 正答率(テスト) = 0.4351
# Generation: 420. 正答率(トレーニング) = 0.61
#                 : 420. 正答率(テスト) = 0.4336
# Generation: 430. 正答率(トレーニング) = 0.44
#                 : 430. 正答率(テスト) = 0.4503
# Generation: 440. 正答率(トレーニング) = 0.44
#                 : 440. 正答率(テスト) = 0.451
# Generation: 450. 正答率(トレーニング) = 0.45
#                 : 450. 正答率(テスト) = 0.4521
# Generation: 460. 正答率(トレーニング) = 0.46
#                 : 460. 正答率(テスト) = 0.4291
# Generation: 470. 正答率(トレーニング) = 0.39
#                 : 470. 正答率(テスト) = 0.4243
# Generation: 480. 正答率(トレーニング) = 0.45
#                 : 480. 正答率(テスト) = 0.4411
# Generation: 490. 正答率(トレーニング) = 0.44
#                 : 490. 正答率(テスト) = 0.4504
# Generation: 500. 正答率(トレーニング) = 0.46
#                 : 500. 正答率(テスト) = 0.4674
# Generation: 510. 正答率(トレーニング) = 0.54
#                 : 510. 正答率(テスト) = 0.4592
# Generation: 520. 正答率(トレーニング) = 0.44
#                 : 520. 正答率(テスト) = 0.4487
# Generation: 530. 正答率(トレーニング) = 0.42
#                 : 530. 正答率(テスト) = 0.446
# Generation: 540. 正答率(トレーニング) = 0.5
#                 : 540. 正答率(テスト) = 0.4658
# Generation: 550. 正答率(トレーニング) = 0.44
#                 : 550. 正答率(テスト) = 0.46
# Generation: 560. 正答率(トレーニング) = 0.5
#                 : 560. 正答率(テスト) = 0.4845
# Generation: 570. 正答率(トレーニング) = 0.5
#                 : 570. 正答率(テスト) = 0.493
# Generation: 580. 正答率(トレーニング) = 0.49
#                 : 580. 正答率(テスト) = 0.4941
# Generation: 590. 正答率(トレーニング) = 0.48
#                 : 590. 正答率(テスト) = 0.5048
# Generation: 600. 正答率(トレーニング) = 0.55
#                 : 600. 正答率(テスト) = 0.5363
# Generation: 610. 正答率(トレーニング) = 0.57
#                 : 610. 正答率(テスト) = 0.5272
# Generation: 620. 正答率(トレーニング) = 0.54
#                 : 620. 正答率(テスト) = 0.5233
# Generation: 630. 正答率(トレーニング) = 0.55
#                 : 630. 正答率(テスト) = 0.5204
# Generation: 640. 正答率(トレーニング) = 0.64
#                 : 640. 正答率(テスト) = 0.5387
# Generation: 650. 正答率(トレーニング) = 0.6
#                 : 650. 正答率(テスト) = 0.5496
# Generation: 660. 正答率(トレーニング) = 0.52
#                 : 660. 正答率(テスト) = 0.5581
# Generation: 670. 正答率(トレーニング) = 0.51
#                 : 670. 正答率(テスト) = 0.539
# Generation: 680. 正答率(トレーニング) = 0.5
#                 : 680. 正答率(テスト) = 0.5502
# Generation: 690. 正答率(トレーニング) = 0.54
#                 : 690. 正答率(テスト) = 0.561
# Generation: 700. 正答率(トレーニング) = 0.56
#                 : 700. 正答率(テスト) = 0.5661
# Generation: 710. 正答率(トレーニング) = 0.62
#                 : 710. 正答率(テスト) = 0.5455
# Generation: 720. 正答率(トレーニング) = 0.62
#                 : 720. 正答率(テスト) = 0.5595
# Generation: 730. 正答率(トレーニング) = 0.57
#                 : 730. 正答率(テスト) = 0.5585
# Generation: 740. 正答率(トレーニング) = 0.51
#                 : 740. 正答率(テスト) = 0.5541
# Generation: 750. 正答率(トレーニング) = 0.61
#                 : 750. 正答率(テスト) = 0.5609
# Generation: 760. 正答率(トレーニング) = 0.6
#                 : 760. 正答率(テスト) = 0.5813
# Generation: 770. 正答率(トレーニング) = 0.56
#                 : 770. 正答率(テスト) = 0.5857
# Generation: 780. 正答率(トレーニング) = 0.64
#                 : 780. 正答率(テスト) = 0.5898
# Generation: 790. 正答率(トレーニング) = 0.56
#                 : 790. 正答率(テスト) = 0.5806
# Generation: 800. 正答率(トレーニング) = 0.64
#                 : 800. 正答率(テスト) = 0.5646
# Generation: 810. 正答率(トレーニング) = 0.51
#                 : 810. 正答率(テスト) = 0.5679
# Generation: 820. 正答率(トレーニング) = 0.61
#                 : 820. 正答率(テスト) = 0.5625
# Generation: 830. 正答率(トレーニング) = 0.58
#                 : 830. 正答率(テスト) = 0.5681
# Generation: 840. 正答率(トレーニング) = 0.55
#                 : 840. 正答率(テスト) = 0.5892
# Generation: 850. 正答率(トレーニング) = 0.56
#                 : 850. 正答率(テスト) = 0.5994
# Generation: 860. 正答率(トレーニング) = 0.65
#                 : 860. 正答率(テスト) = 0.5984
# Generation: 870. 正答率(トレーニング) = 0.62
#                 : 870. 正答率(テスト) = 0.602
# Generation: 880. 正答率(トレーニング) = 0.6
#                 : 880. 正答率(テスト) = 0.5955
# Generation: 890. 正答率(トレーニング) = 0.56
#                 : 890. 正答率(テスト) = 0.5819
# Generation: 900. 正答率(トレーニング) = 0.54
#                 : 900. 正答率(テスト) = 0.569
# Generation: 910. 正答率(トレーニング) = 0.65
#                 : 910. 正答率(テスト) = 0.5896
# Generation: 920. 正答率(トレーニング) = 0.65
#                 : 920. 正答率(テスト) = 0.6037
# Generation: 930. 正答率(トレーニング) = 0.67
#                 : 930. 正答率(テスト) = 0.5965
# Generation: 940. 正答率(トレーニング) = 0.67
#                 : 940. 正答率(テスト) = 0.6031
# Generation: 950. 正答率(トレーニング) = 0.58
#                 : 950. 正答率(テスト) = 0.6112
# Generation: 960. 正答率(トレーニング) = 0.59
#                 : 960. 正答率(テスト) = 0.6219
# Generation: 970. 正答率(トレーニング) = 0.61
#                 : 970. 正答率(テスト) = 0.6176
# Generation: 980. 正答率(トレーニング) = 0.67
#                 : 980. 正答率(テスト) = 0.6142
# Generation: 990. 正答率(トレーニング) = 0.61
#                 : 990. 正答率(テスト) = 0.6201
# Generation: 1000. 正答率(トレーニング) = 0.58
#                 : 1000. 正答率(テスト) = 0.5982

# %% [markdown]
# ## Momentum

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

# batch_normalizationの設定 ================================
use_batchnorm = True
# use_batchnorm = False
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='sigmoid', weight_init_std=0.01,
                       use_batchnorm=use_batchnorm)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01
# 慣性
momentum = 0.9

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    if i == 0:
        v = {}
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        if i == 0:
            v[key] = np.zeros_like(network.params[key])
        v[key] = momentum * v[key] - learning_rate * grad[key]  # Momentumの計算
        network.params[key] += v[key]  # Momentumでの重み更新

        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)
        
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        
        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.12
#                 : 10. 正答率(テスト) = 0.1135
# Generation: 20. 正答率(トレーニング) = 0.09
#                 : 20. 正答率(テスト) = 0.1135
# Generation: 30. 正答率(トレーニング) = 0.18
#                 : 30. 正答率(テスト) = 0.1135
# Generation: 40. 正答率(トレーニング) = 0.1
#                 : 40. 正答率(テスト) = 0.1135
# Generation: 50. 正答率(トレーニング) = 0.1
#                 : 50. 正答率(テスト) = 0.1135
# Generation: 60. 正答率(トレーニング) = 0.06
#                 : 60. 正答率(テスト) = 0.1135
# Generation: 70. 正答率(トレーニング) = 0.09
#                 : 70. 正答率(テスト) = 0.1135
# Generation: 80. 正答率(トレーニング) = 0.11
#                 : 80. 正答率(テスト) = 0.1135
# Generation: 90. 正答率(トレーニング) = 0.13
#                 : 90. 正答率(テスト) = 0.1135
# Generation: 100. 正答率(トレーニング) = 0.11
#                 : 100. 正答率(テスト) = 0.0982
# Generation: 110. 正答率(トレーニング) = 0.07
#                 : 110. 正答率(テスト) = 0.101
# Generation: 120. 正答率(トレーニング) = 0.12
#                 : 120. 正答率(テスト) = 0.101
# Generation: 130. 正答率(トレーニング) = 0.1
#                 : 130. 正答率(テスト) = 0.1135
# Generation: 140. 正答率(トレーニング) = 0.13
#                 : 140. 正答率(テスト) = 0.1135
# Generation: 150. 正答率(トレーニング) = 0.13
#                 : 150. 正答率(テスト) = 0.1135
# Generation: 160. 正答率(トレーニング) = 0.15
#                 : 160. 正答率(テスト) = 0.1135
# Generation: 170. 正答率(トレーニング) = 0.1
#                 : 170. 正答率(テスト) = 0.1135
# Generation: 180. 正答率(トレーニング) = 0.16
#                 : 180. 正答率(テスト) = 0.0974
# Generation: 190. 正答率(トレーニング) = 0.07
#                 : 190. 正答率(テスト) = 0.101
# Generation: 200. 正答率(トレーニング) = 0.16
#                 : 200. 正答率(テスト) = 0.1135
# Generation: 210. 正答率(トレーニング) = 0.05
#                 : 210. 正答率(テスト) = 0.1135
# Generation: 220. 正答率(トレーニング) = 0.11
#                 : 220. 正答率(テスト) = 0.1135
# Generation: 230. 正答率(トレーニング) = 0.06
#                 : 230. 正答率(テスト) = 0.1028
# Generation: 240. 正答率(トレーニング) = 0.08
#                 : 240. 正答率(テスト) = 0.1135
# Generation: 250. 正答率(トレーニング) = 0.11
#                 : 250. 正答率(テスト) = 0.1135
# Generation: 260. 正答率(トレーニング) = 0.12
#                 : 260. 正答率(テスト) = 0.1135
# Generation: 270. 正答率(トレーニング) = 0.11
#                 : 270. 正答率(テスト) = 0.1135
# Generation: 280. 正答率(トレーニング) = 0.08
#                 : 280. 正答率(テスト) = 0.1135
# Generation: 290. 正答率(トレーニング) = 0.11
#                 : 290. 正答率(テスト) = 0.1135
# Generation: 300. 正答率(トレーニング) = 0.09
#                 : 300. 正答率(テスト) = 0.1135
# Generation: 310. 正答率(トレーニング) = 0.09
#                 : 310. 正答率(テスト) = 0.1135
# Generation: 320. 正答率(トレーニング) = 0.15
#                 : 320. 正答率(テスト) = 0.1135
# Generation: 330. 正答率(トレーニング) = 0.13
#                 : 330. 正答率(テスト) = 0.1135
# Generation: 340. 正答率(トレーニング) = 0.1
#                 : 340. 正答率(テスト) = 0.1135
# Generation: 350. 正答率(トレーニング) = 0.08
#                 : 350. 正答率(テスト) = 0.1009
# Generation: 360. 正答率(トレーニング) = 0.09
#                 : 360. 正答率(テスト) = 0.1135
# Generation: 370. 正答率(トレーニング) = 0.14
#                 : 370. 正答率(テスト) = 0.098
# Generation: 380. 正答率(トレーニング) = 0.13
#                 : 380. 正答率(テスト) = 0.098
# Generation: 390. 正答率(トレーニング) = 0.08
#                 : 390. 正答率(テスト) = 0.098
# Generation: 400. 正答率(トレーニング) = 0.09
#                 : 400. 正答率(テスト) = 0.1135
# Generation: 410. 正答率(トレーニング) = 0.1
#                 : 410. 正答率(テスト) = 0.0974
# Generation: 420. 正答率(トレーニング) = 0.1
#                 : 420. 正答率(テスト) = 0.1135
# Generation: 430. 正答率(トレーニング) = 0.06
#                 : 430. 正答率(テスト) = 0.1135
# Generation: 440. 正答率(トレーニング) = 0.11
#                 : 440. 正答率(テスト) = 0.1135
# Generation: 450. 正答率(トレーニング) = 0.07
#                 : 450. 正答率(テスト) = 0.1135
# Generation: 460. 正答率(トレーニング) = 0.07
#                 : 460. 正答率(テスト) = 0.1135
# Generation: 470. 正答率(トレーニング) = 0.07
#                 : 470. 正答率(テスト) = 0.1135
# Generation: 480. 正答率(トレーニング) = 0.13
#                 : 480. 正答率(テスト) = 0.1135
# Generation: 490. 正答率(トレーニング) = 0.13
#                 : 490. 正答率(テスト) = 0.1028
# Generation: 500. 正答率(トレーニング) = 0.05
#                 : 500. 正答率(テスト) = 0.1028
# Generation: 510. 正答率(トレーニング) = 0.09
#                 : 510. 正答率(テスト) = 0.1135
# Generation: 520. 正答率(トレーニング) = 0.1
#                 : 520. 正答率(テスト) = 0.1135
# Generation: 530. 正答率(トレーニング) = 0.12
#                 : 530. 正答率(テスト) = 0.1135
# Generation: 540. 正答率(トレーニング) = 0.12
#                 : 540. 正答率(テスト) = 0.1135
# Generation: 550. 正答率(トレーニング) = 0.14
#                 : 550. 正答率(テスト) = 0.1135
# Generation: 560. 正答率(トレーニング) = 0.1
#                 : 560. 正答率(テスト) = 0.1135
# Generation: 570. 正答率(トレーニング) = 0.13
#                 : 570. 正答率(テスト) = 0.1135
# Generation: 580. 正答率(トレーニング) = 0.19
#                 : 580. 正答率(テスト) = 0.1135
# Generation: 590. 正答率(トレーニング) = 0.08
#                 : 590. 正答率(テスト) = 0.1135
# Generation: 600. 正答率(トレーニング) = 0.02
#                 : 600. 正答率(テスト) = 0.101
# Generation: 610. 正答率(トレーニング) = 0.12
#                 : 610. 正答率(テスト) = 0.101
# Generation: 620. 正答率(トレーニング) = 0.09
#                 : 620. 正答率(テスト) = 0.1135
# Generation: 630. 正答率(トレーニング) = 0.16
#                 : 630. 正答率(テスト) = 0.1135
# Generation: 640. 正答率(トレーニング) = 0.07
#                 : 640. 正答率(テスト) = 0.1135
# Generation: 650. 正答率(トレーニング) = 0.1
#                 : 650. 正答率(テスト) = 0.1135
# Generation: 660. 正答率(トレーニング) = 0.07
#                 : 660. 正答率(テスト) = 0.1135
# Generation: 670. 正答率(トレーニング) = 0.11
#                 : 670. 正答率(テスト) = 0.1135
# Generation: 680. 正答率(トレーニング) = 0.1
#                 : 680. 正答率(テスト) = 0.1135
# Generation: 690. 正答率(トレーニング) = 0.12
#                 : 690. 正答率(テスト) = 0.1135
# Generation: 700. 正答率(トレーニング) = 0.09
#                 : 700. 正答率(テスト) = 0.1028
# Generation: 710. 正答率(トレーニング) = 0.19
#                 : 710. 正答率(テスト) = 0.1028
# Generation: 720. 正答率(トレーニング) = 0.13
#                 : 720. 正答率(テスト) = 0.1028
# Generation: 730. 正答率(トレーニング) = 0.1
#                 : 730. 正答率(テスト) = 0.1028
# Generation: 740. 正答率(トレーニング) = 0.11
#                 : 740. 正答率(テスト) = 0.1028
# Generation: 750. 正答率(トレーニング) = 0.1
#                 : 750. 正答率(テスト) = 0.1135
# Generation: 760. 正答率(トレーニング) = 0.12
#                 : 760. 正答率(テスト) = 0.1135
# Generation: 770. 正答率(トレーニング) = 0.08
#                 : 770. 正答率(テスト) = 0.1135
# Generation: 780. 正答率(トレーニング) = 0.16
#                 : 780. 正答率(テスト) = 0.1135
# Generation: 790. 正答率(トレーニング) = 0.1
#                 : 790. 正答率(テスト) = 0.1135
# Generation: 800. 正答率(トレーニング) = 0.1
#                 : 800. 正答率(テスト) = 0.1135
# Generation: 810. 正答率(トレーニング) = 0.11
#                 : 810. 正答率(テスト) = 0.0958
# Generation: 820. 正答率(トレーニング) = 0.12
#                 : 820. 正答率(テスト) = 0.0958
# Generation: 830. 正答率(トレーニング) = 0.11
#                 : 830. 正答率(テスト) = 0.0958
# Generation: 840. 正答率(トレーニング) = 0.06
#                 : 840. 正答率(テスト) = 0.0958
# Generation: 850. 正答率(トレーニング) = 0.09
#                 : 850. 正答率(テスト) = 0.1135
# Generation: 860. 正答率(トレーニング) = 0.1
#                 : 860. 正答率(テスト) = 0.101
# Generation: 870. 正答率(トレーニング) = 0.12
#                 : 870. 正答率(テスト) = 0.101
# Generation: 880. 正答率(トレーニング) = 0.13
#                 : 880. 正答率(テスト) = 0.101
# Generation: 890. 正答率(トレーニング) = 0.14
#                 : 890. 正答率(テスト) = 0.1135
# Generation: 900. 正答率(トレーニング) = 0.13
#                 : 900. 正答率(テスト) = 0.1135
# Generation: 910. 正答率(トレーニング) = 0.09
#                 : 910. 正答率(テスト) = 0.1135
# Generation: 920. 正答率(トレーニング) = 0.1
#                 : 920. 正答率(テスト) = 0.1135
# Generation: 930. 正答率(トレーニング) = 0.11
#                 : 930. 正答率(テスト) = 0.1028
# Generation: 940. 正答率(トレーニング) = 0.12
#                 : 940. 正答率(テスト) = 0.1009
# Generation: 950. 正答率(トレーニング) = 0.07
#                 : 950. 正答率(テスト) = 0.1009
# Generation: 960. 正答率(トレーニング) = 0.08
#                 : 960. 正答率(テスト) = 0.1028
# Generation: 970. 正答率(トレーニング) = 0.09
#                 : 970. 正答率(テスト) = 0.1135
# Generation: 980. 正答率(トレーニング) = 0.1
#                 : 980. 正答率(テスト) = 0.1028
# Generation: 990. 正答率(トレーニング) = 0.09
#                 : 990. 正答率(テスト) = 0.1028
# Generation: 1000. 正答率(トレーニング) = 0.07
#                 : 1000. 正答率(テスト) = 0.1028

# %% [markdown]
# ## MomentumをもとにAdaGradを作ってみよう
# θ = 1e-4 とする

# %%
# AdaGradを作ってみよう
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

# batch_normalizationの設定 ================================
use_batchnorm = True
# use_batchnorm = False
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='sigmoid', weight_init_std=0.01,
                       use_batchnorm=use_batchnorm)

iters_num = 1000
# iters_num = 500 # 処理を短縮

train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01

# AdaGradでは不必要
# =============================

momentum = 0.9 

# =============================

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    if i == 0:
        h = {}
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
            
        # 変更しよう  
        # ===========================================
        if i == 0:
            h[key] = np.zeros_like(network.params[key])        
        h[key] = momentum * h[key] - learning_rate * grad[key]  #Adagradの計算
        network.params[key] += h[key]  # Adagradでの重み更新

        # ===========================================
        
        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)
        
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        
        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.04
#                 : 10. 正答率(テスト) = 0.1135
# Generation: 20. 正答率(トレーニング) = 0.12
#                 : 20. 正答率(テスト) = 0.101
# Generation: 30. 正答率(トレーニング) = 0.1
#                 : 30. 正答率(テスト) = 0.101
# Generation: 40. 正答率(トレーニング) = 0.12
#                 : 40. 正答率(テスト) = 0.1009
# Generation: 50. 正答率(トレーニング) = 0.13
#                 : 50. 正答率(テスト) = 0.1028
# Generation: 60. 正答率(トレーニング) = 0.09
#                 : 60. 正答率(テスト) = 0.1135
# Generation: 70. 正答率(トレーニング) = 0.09
#                 : 70. 正答率(テスト) = 0.1135
# Generation: 80. 正答率(トレーニング) = 0.16
#                 : 80. 正答率(テスト) = 0.1135
# Generation: 90. 正答率(トレーニング) = 0.1
#                 : 90. 正答率(テスト) = 0.1135
# Generation: 100. 正答率(トレーニング) = 0.1
#                 : 100. 正答率(テスト) = 0.1135
# Generation: 110. 正答率(トレーニング) = 0.08
#                 : 110. 正答率(テスト) = 0.1135
# Generation: 120. 正答率(トレーニング) = 0.09
#                 : 120. 正答率(テスト) = 0.1135
# Generation: 130. 正答率(トレーニング) = 0.14
#                 : 130. 正答率(テスト) = 0.1135
# Generation: 140. 正答率(トレーニング) = 0.09
#                 : 140. 正答率(テスト) = 0.1135
# Generation: 150. 正答率(トレーニング) = 0.18
#                 : 150. 正答率(テスト) = 0.1135
# Generation: 160. 正答率(トレーニング) = 0.11
#                 : 160. 正答率(テスト) = 0.1135
# Generation: 170. 正答率(トレーニング) = 0.16
#                 : 170. 正答率(テスト) = 0.1135
# Generation: 180. 正答率(トレーニング) = 0.11
#                 : 180. 正答率(テスト) = 0.098
# Generation: 190. 正答率(トレーニング) = 0.15
#                 : 190. 正答率(テスト) = 0.101
# Generation: 200. 正答率(トレーニング) = 0.09
#                 : 200. 正答率(テスト) = 0.101
# Generation: 210. 正答率(トレーニング) = 0.13
#                 : 210. 正答率(テスト) = 0.1135
# Generation: 220. 正答率(トレーニング) = 0.19
#                 : 220. 正答率(テスト) = 0.1135
# Generation: 230. 正答率(トレーニング) = 0.1
#                 : 230. 正答率(テスト) = 0.0958
# Generation: 240. 正答率(トレーニング) = 0.1
#                 : 240. 正答率(テスト) = 0.1028
# Generation: 250. 正答率(トレーニング) = 0.12
#                 : 250. 正答率(テスト) = 0.1028
# Generation: 260. 正答率(トレーニング) = 0.06
#                 : 260. 正答率(テスト) = 0.098
# Generation: 270. 正答率(トレーニング) = 0.14
#                 : 270. 正答率(テスト) = 0.1135
# Generation: 280. 正答率(トレーニング) = 0.13
#                 : 280. 正答率(テスト) = 0.1135
# Generation: 290. 正答率(トレーニング) = 0.1
#                 : 290. 正答率(テスト) = 0.1135
# Generation: 300. 正答率(トレーニング) = 0.18
#                 : 300. 正答率(テスト) = 0.101
# Generation: 310. 正答率(トレーニング) = 0.12
#                 : 310. 正答率(テスト) = 0.101
# Generation: 320. 正答率(トレーニング) = 0.12
#                 : 320. 正答率(テスト) = 0.1135
# Generation: 330. 正答率(トレーニング) = 0.14
#                 : 330. 正答率(テスト) = 0.1135
# Generation: 340. 正答率(トレーニング) = 0.11
#                 : 340. 正答率(テスト) = 0.1135
# Generation: 350. 正答率(トレーニング) = 0.14
#                 : 350. 正答率(テスト) = 0.1135
# Generation: 360. 正答率(トレーニング) = 0.15
#                 : 360. 正答率(テスト) = 0.1028
# Generation: 370. 正答率(トレーニング) = 0.07
#                 : 370. 正答率(テスト) = 0.1028
# Generation: 380. 正答率(トレーニング) = 0.14
#                 : 380. 正答率(テスト) = 0.1135
# Generation: 390. 正答率(トレーニング) = 0.16
#                 : 390. 正答率(テスト) = 0.1135
# Generation: 400. 正答率(トレーニング) = 0.09
#                 : 400. 正答率(テスト) = 0.1135
# Generation: 410. 正答率(トレーニング) = 0.06
#                 : 410. 正答率(テスト) = 0.1135
# Generation: 420. 正答率(トレーニング) = 0.15
#                 : 420. 正答率(テスト) = 0.1135
# Generation: 430. 正答率(トレーニング) = 0.12
#                 : 430. 正答率(テスト) = 0.1135
# Generation: 440. 正答率(トレーニング) = 0.16
#                 : 440. 正答率(テスト) = 0.1135
# Generation: 450. 正答率(トレーニング) = 0.11
#                 : 450. 正答率(テスト) = 0.1135
# Generation: 460. 正答率(トレーニング) = 0.08
#                 : 460. 正答率(テスト) = 0.1135
# Generation: 470. 正答率(トレーニング) = 0.16
#                 : 470. 正答率(テスト) = 0.1135
# Generation: 480. 正答率(トレーニング) = 0.1
#                 : 480. 正答率(テスト) = 0.1135
# Generation: 490. 正答率(トレーニング) = 0.1
#                 : 490. 正答率(テスト) = 0.1135
# Generation: 500. 正答率(トレーニング) = 0.15
#                 : 500. 正答率(テスト) = 0.1135
# Generation: 510. 正答率(トレーニング) = 0.11
#                 : 510. 正答率(テスト) = 0.1135
# Generation: 520. 正答率(トレーニング) = 0.06
#                 : 520. 正答率(テスト) = 0.1135
# Generation: 530. 正答率(トレーニング) = 0.06
#                 : 530. 正答率(テスト) = 0.1028
# Generation: 540. 正答率(トレーニング) = 0.11
#                 : 540. 正答率(テスト) = 0.1135
# Generation: 550. 正答率(トレーニング) = 0.1
#                 : 550. 正答率(テスト) = 0.1135
# Generation: 560. 正答率(トレーニング) = 0.1
#                 : 560. 正答率(テスト) = 0.1135
# Generation: 570. 正答率(トレーニング) = 0.13
#                 : 570. 正答率(テスト) = 0.1135
# Generation: 580. 正答率(トレーニング) = 0.18
#                 : 580. 正答率(テスト) = 0.1135
# Generation: 590. 正答率(トレーニング) = 0.12
#                 : 590. 正答率(テスト) = 0.1135
# Generation: 600. 正答率(トレーニング) = 0.09
#                 : 600. 正答率(テスト) = 0.1135
# Generation: 610. 正答率(トレーニング) = 0.13
#                 : 610. 正答率(テスト) = 0.1135
# Generation: 620. 正答率(トレーニング) = 0.11
#                 : 620. 正答率(テスト) = 0.1028
# Generation: 630. 正答率(トレーニング) = 0.13
#                 : 630. 正答率(テスト) = 0.1028
# Generation: 640. 正答率(トレーニング) = 0.07
#                 : 640. 正答率(テスト) = 0.1028
# Generation: 650. 正答率(トレーニング) = 0.13
#                 : 650. 正答率(テスト) = 0.1135
# Generation: 660. 正答率(トレーニング) = 0.13
#                 : 660. 正答率(テスト) = 0.1135
# Generation: 670. 正答率(トレーニング) = 0.07
#                 : 670. 正答率(テスト) = 0.1135
# Generation: 680. 正答率(トレーニング) = 0.11
#                 : 680. 正答率(テスト) = 0.1135
# Generation: 690. 正答率(トレーニング) = 0.12
#                 : 690. 正答率(テスト) = 0.1135
# Generation: 700. 正答率(トレーニング) = 0.1
#                 : 700. 正答率(テスト) = 0.1135
# Generation: 710. 正答率(トレーニング) = 0.08
#                 : 710. 正答率(テスト) = 0.101
# Generation: 720. 正答率(トレーニング) = 0.15
#                 : 720. 正答率(テスト) = 0.1135
# Generation: 730. 正答率(トレーニング) = 0.11
#                 : 730. 正答率(テスト) = 0.1135
# Generation: 740. 正答率(トレーニング) = 0.13
#                 : 740. 正答率(テスト) = 0.1135
# Generation: 750. 正答率(トレーニング) = 0.11
#                 : 750. 正答率(テスト) = 0.1135
# Generation: 760. 正答率(トレーニング) = 0.06
#                 : 760. 正答率(テスト) = 0.1135
# Generation: 770. 正答率(トレーニング) = 0.13
#                 : 770. 正答率(テスト) = 0.1135
# Generation: 780. 正答率(トレーニング) = 0.12
#                 : 780. 正答率(テスト) = 0.1135
# Generation: 790. 正答率(トレーニング) = 0.13
#                 : 790. 正答率(テスト) = 0.1135
# Generation: 800. 正答率(トレーニング) = 0.06
#                 : 800. 正答率(テスト) = 0.1135
# Generation: 810. 正答率(トレーニング) = 0.05
#                 : 810. 正答率(テスト) = 0.1135
# Generation: 820. 正答率(トレーニング) = 0.12
#                 : 820. 正答率(テスト) = 0.1135
# Generation: 830. 正答率(トレーニング) = 0.16
#                 : 830. 正答率(テスト) = 0.1135
# Generation: 840. 正答率(トレーニング) = 0.09
#                 : 840. 正答率(テスト) = 0.1135
# Generation: 850. 正答率(トレーニング) = 0.1
#                 : 850. 正答率(テスト) = 0.1135
# Generation: 860. 正答率(トレーニング) = 0.08
#                 : 860. 正答率(テスト) = 0.1135
# Generation: 870. 正答率(トレーニング) = 0.13
#                 : 870. 正答率(テスト) = 0.0974
# Generation: 880. 正答率(トレーニング) = 0.13
#                 : 880. 正答率(テスト) = 0.0974
# Generation: 890. 正答率(トレーニング) = 0.14
#                 : 890. 正答率(テスト) = 0.1135
# Generation: 900. 正答率(トレーニング) = 0.12
#                 : 900. 正答率(テスト) = 0.1135
# Generation: 910. 正答率(トレーニング) = 0.1
#                 : 910. 正答率(テスト) = 0.1135
# Generation: 920. 正答率(トレーニング) = 0.12
#                 : 920. 正答率(テスト) = 0.1135
# Generation: 930. 正答率(トレーニング) = 0.07
#                 : 930. 正答率(テスト) = 0.1028
# Generation: 940. 正答率(トレーニング) = 0.12
#                 : 940. 正答率(テスト) = 0.1028
# Generation: 950. 正答率(トレーニング) = 0.15
#                 : 950. 正答率(テスト) = 0.1135
# Generation: 960. 正答率(トレーニング) = 0.12
#                 : 960. 正答率(テスト) = 0.1135
# Generation: 970. 正答率(トレーニング) = 0.07
#                 : 970. 正答率(テスト) = 0.1135
# Generation: 980. 正答率(トレーニング) = 0.1
#                 : 980. 正答率(テスト) = 0.1009
# Generation: 990. 正答率(トレーニング) = 0.15
#                 : 990. 正答率(テスト) = 0.1135
# Generation: 1000. 正答率(トレーニング) = 0.17
#                 : 1000. 正答率(テスト) = 0.1135

# %% [markdown]
# ## RMSprop

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

# batch_normalizationの設定 ================================
use_batchnorm = True
# use_batchnorm = False
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='sigmoid', weight_init_std=0.01,
                       use_batchnorm=use_batchnorm)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01
decay_rate = 0.99

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    if i == 0:
        h = {}
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        if i == 0:
            h[key] = np.zeros_like(network.params[key])
        h[key] *= decay_rate
        h[key] += (1 - decay_rate) * np.square(grad[key])  # hの計算
        network.params[key] -= learning_rate * grad[key] / (np.sqrt(h[key]) + 1e-7)  # RMSdropの計算

        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)                
        
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        
        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.11
#                 : 10. 正答率(テスト) = 0.1028
# Generation: 20. 正答率(トレーニング) = 0.11
#                 : 20. 正答率(テスト) = 0.1135
# Generation: 30. 正答率(トレーニング) = 0.28
#                 : 30. 正答率(テスト) = 0.2119
# Generation: 40. 正答率(トレーニング) = 0.25
#                 : 40. 正答率(テスト) = 0.2041
# Generation: 50. 正答率(トレーニング) = 0.17
#                 : 50. 正答率(テスト) = 0.2136
# Generation: 60. 正答率(トレーニング) = 0.27
#                 : 60. 正答率(テスト) = 0.2141
# Generation: 70. 正答率(トレーニング) = 0.18
#                 : 70. 正答率(テスト) = 0.2125
# Generation: 80. 正答率(トレーニング) = 0.24
#                 : 80. 正答率(テスト) = 0.2137
# Generation: 90. 正答率(トレーニング) = 0.19
#                 : 90. 正答率(テスト) = 0.2147
# Generation: 100. 正答率(トレーニング) = 0.28
#                 : 100. 正答率(テスト) = 0.2264
# Generation: 110. 正答率(トレーニング) = 0.21
#                 : 110. 正答率(テスト) = 0.2436
# Generation: 120. 正答率(トレーニング) = 0.25
#                 : 120. 正答率(テスト) = 0.2605
# Generation: 130. 正答率(トレーニング) = 0.27
#                 : 130. 正答率(テスト) = 0.2836
# Generation: 140. 正答率(トレーニング) = 0.24
#                 : 140. 正答率(テスト) = 0.2813
# Generation: 150. 正答率(トレーニング) = 0.35
#                 : 150. 正答率(テスト) = 0.2834
# Generation: 160. 正答率(トレーニング) = 0.35
#                 : 160. 正答率(テスト) = 0.3908
# Generation: 170. 正答率(トレーニング) = 0.57
#                 : 170. 正答率(テスト) = 0.5763
# Generation: 180. 正答率(トレーニング) = 0.58
#                 : 180. 正答率(テスト) = 0.5213
# Generation: 190. 正答率(トレーニング) = 0.77
#                 : 190. 正答率(テスト) = 0.6424
# Generation: 200. 正答率(トレーニング) = 0.79
#                 : 200. 正答率(テスト) = 0.6941
# Generation: 210. 正答率(トレーニング) = 0.76
#                 : 210. 正答率(テスト) = 0.7147
# Generation: 220. 正答率(トレーニング) = 0.81
#                 : 220. 正答率(テスト) = 0.8035
# Generation: 230. 正答率(トレーニング) = 0.92
#                 : 230. 正答率(テスト) = 0.7991
# Generation: 240. 正答率(トレーニング) = 0.9
#                 : 240. 正答率(テスト) = 0.8464
# Generation: 250. 正答率(トレーニング) = 0.88
#                 : 250. 正答率(テスト) = 0.8509
# Generation: 260. 正答率(トレーニング) = 0.92
#                 : 260. 正答率(テスト) = 0.8694
# Generation: 270. 正答率(トレーニング) = 0.91
#                 : 270. 正答率(テスト) = 0.8777
# Generation: 280. 正答率(トレーニング) = 0.97
#                 : 280. 正答率(テスト) = 0.8837
# Generation: 290. 正答率(トレーニング) = 0.94
#                 : 290. 正答率(テスト) = 0.8744
# Generation: 300. 正答率(トレーニング) = 0.93
#                 : 300. 正答率(テスト) = 0.8897
# Generation: 310. 正答率(トレーニング) = 0.99
#                 : 310. 正答率(テスト) = 0.8873
# Generation: 320. 正答率(トレーニング) = 0.93
#                 : 320. 正答率(テスト) = 0.8899
# Generation: 330. 正答率(トレーニング) = 0.93
#                 : 330. 正答率(テスト) = 0.8888
# Generation: 340. 正答率(トレーニング) = 0.91
#                 : 340. 正答率(テスト) = 0.9027
# Generation: 350. 正答率(トレーニング) = 0.96
#                 : 350. 正答率(テスト) = 0.9054
# Generation: 360. 正答率(トレーニング) = 0.96
#                 : 360. 正答率(テスト) = 0.9067
# Generation: 370. 正答率(トレーニング) = 0.98
#                 : 370. 正答率(テスト) = 0.9043
# Generation: 380. 正答率(トレーニング) = 0.97
#                 : 380. 正答率(テスト) = 0.9049
# Generation: 390. 正答率(トレーニング) = 0.94
#                 : 390. 正答率(テスト) = 0.9091
# Generation: 400. 正答率(トレーニング) = 0.92
#                 : 400. 正答率(テスト) = 0.9022
# Generation: 410. 正答率(トレーニング) = 0.96
#                 : 410. 正答率(テスト) = 0.9116
# Generation: 420. 正答率(トレーニング) = 0.96
#                 : 420. 正答率(テスト) = 0.9164
# Generation: 430. 正答率(トレーニング) = 0.98
#                 : 430. 正答率(テスト) = 0.9122
# Generation: 440. 正答率(トレーニング) = 0.99
#                 : 440. 正答率(テスト) = 0.9209
# Generation: 450. 正答率(トレーニング) = 0.94
#                 : 450. 正答率(テスト) = 0.9191
# Generation: 460. 正答率(トレーニング) = 0.95
#                 : 460. 正答率(テスト) = 0.9194
# Generation: 470. 正答率(トレーニング) = 0.94
#                 : 470. 正答率(テスト) = 0.9182
# Generation: 480. 正答率(トレーニング) = 0.95
#                 : 480. 正答率(テスト) = 0.9237
# Generation: 490. 正答率(トレーニング) = 0.97
#                 : 490. 正答率(テスト) = 0.9259
# Generation: 500. 正答率(トレーニング) = 0.98
#                 : 500. 正答率(テスト) = 0.9251
# Generation: 510. 正答率(トレーニング) = 0.98
#                 : 510. 正答率(テスト) = 0.9297
# Generation: 520. 正答率(トレーニング) = 0.95
#                 : 520. 正答率(テスト) = 0.9292
# Generation: 530. 正答率(トレーニング) = 0.98
#                 : 530. 正答率(テスト) = 0.9203
# Generation: 540. 正答率(トレーニング) = 0.96
#                 : 540. 正答率(テスト) = 0.9252
# Generation: 550. 正答率(トレーニング) = 0.96
#                 : 550. 正答率(テスト) = 0.928
# Generation: 560. 正答率(トレーニング) = 0.97
#                 : 560. 正答率(テスト) = 0.9265
# Generation: 570. 正答率(トレーニング) = 0.98
#                 : 570. 正答率(テスト) = 0.9318
# Generation: 580. 正答率(トレーニング) = 0.96
#                 : 580. 正答率(テスト) = 0.9287
# Generation: 590. 正答率(トレーニング) = 0.95
#                 : 590. 正答率(テスト) = 0.9295
# Generation: 600. 正答率(トレーニング) = 0.96
#                 : 600. 正答率(テスト) = 0.9349
# Generation: 610. 正答率(トレーニング) = 0.98
#                 : 610. 正答率(テスト) = 0.9238
# Generation: 620. 正答率(トレーニング) = 0.97
#                 : 620. 正答率(テスト) = 0.9294
# Generation: 630. 正答率(トレーニング) = 0.97
#                 : 630. 正答率(テスト) = 0.9314
# Generation: 640. 正答率(トレーニング) = 0.99
#                 : 640. 正答率(テスト) = 0.9362
# Generation: 650. 正答率(トレーニング) = 0.97
#                 : 650. 正答率(テスト) = 0.9335
# Generation: 660. 正答率(トレーニング) = 0.99
#                 : 660. 正答率(テスト) = 0.9362
# Generation: 670. 正答率(トレーニング) = 1.0
#                 : 670. 正答率(テスト) = 0.9371
# Generation: 680. 正答率(トレーニング) = 0.93
#                 : 680. 正答率(テスト) = 0.9361
# Generation: 690. 正答率(トレーニング) = 0.97
#                 : 690. 正答率(テスト) = 0.9391
# Generation: 700. 正答率(トレーニング) = 0.98
#                 : 700. 正答率(テスト) = 0.9367
# Generation: 710. 正答率(トレーニング) = 0.96
#                 : 710. 正答率(テスト) = 0.9391
# Generation: 720. 正答率(トレーニング) = 0.98
#                 : 720. 正答率(テスト) = 0.9391
# Generation: 730. 正答率(トレーニング) = 0.96
#                 : 730. 正答率(テスト) = 0.9366
# Generation: 740. 正答率(トレーニング) = 0.97
#                 : 740. 正答率(テスト) = 0.939
# Generation: 750. 正答率(トレーニング) = 0.99
#                 : 750. 正答率(テスト) = 0.9402
# Generation: 760. 正答率(トレーニング) = 0.98
#                 : 760. 正答率(テスト) = 0.9408
# Generation: 770. 正答率(トレーニング) = 0.99
#                 : 770. 正答率(テスト) = 0.9408
# Generation: 780. 正答率(トレーニング) = 0.98
#                 : 780. 正答率(テスト) = 0.9265
# Generation: 790. 正答率(トレーニング) = 0.99
#                 : 790. 正答率(テスト) = 0.9425
# Generation: 800. 正答率(トレーニング) = 0.94
#                 : 800. 正答率(テスト) = 0.942
# Generation: 810. 正答率(トレーニング) = 0.97
#                 : 810. 正答率(テスト) = 0.9401
# Generation: 820. 正答率(トレーニング) = 0.99
#                 : 820. 正答率(テスト) = 0.944
# Generation: 830. 正答率(トレーニング) = 0.99
#                 : 830. 正答率(テスト) = 0.9383
# Generation: 840. 正答率(トレーニング) = 0.96
#                 : 840. 正答率(テスト) = 0.9378
# Generation: 850. 正答率(トレーニング) = 0.97
#                 : 850. 正答率(テスト) = 0.935
# Generation: 860. 正答率(トレーニング) = 0.99
#                 : 860. 正答率(テスト) = 0.9469
# Generation: 870. 正答率(トレーニング) = 0.98
#                 : 870. 正答率(テスト) = 0.9425
# Generation: 880. 正答率(トレーニング) = 1.0
#                 : 880. 正答率(テスト) = 0.9436
# Generation: 890. 正答率(トレーニング) = 0.97
#                 : 890. 正答率(テスト) = 0.9419
# Generation: 900. 正答率(トレーニング) = 0.98
#                 : 900. 正答率(テスト) = 0.9426
# Generation: 910. 正答率(トレーニング) = 1.0
#                 : 910. 正答率(テスト) = 0.9435
# Generation: 920. 正答率(トレーニング) = 0.98
#                 : 920. 正答率(テスト) = 0.9411
# Generation: 930. 正答率(トレーニング) = 0.98
#                 : 930. 正答率(テスト) = 0.9444
# Generation: 940. 正答率(トレーニング) = 0.96
#                 : 940. 正答率(テスト) = 0.9454
# Generation: 950. 正答率(トレーニング) = 0.98
#                 : 950. 正答率(テスト) = 0.9466
# Generation: 960. 正答率(トレーニング) = 0.97
#                 : 960. 正答率(テスト) = 0.9439
# Generation: 970. 正答率(トレーニング) = 1.0
#                 : 970. 正答率(テスト) = 0.9462
# Generation: 980. 正答率(トレーニング) = 0.98
#                 : 980. 正答率(テスト) = 0.9444
# Generation: 990. 正答率(トレーニング) = 0.99
#                 : 990. 正答率(テスト) = 0.9443
# Generation: 1000. 正答率(トレーニング) = 0.99
#                 : 1000. 正答率(テスト) = 0.9452

# %% [markdown]
# ## Adam

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

# batch_normalizationの設定 ================================
use_batchnorm = True
# use_batchnorm = False
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='sigmoid', weight_init_std=0.01,
                       use_batchnorm=use_batchnorm)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01
beta1 = 0.9
beta2 = 0.999

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    if i == 0:
        m = {}
        v = {}
    learning_rate_t  = learning_rate * np.sqrt(1.0 - beta2 ** (i + 1)) / (1.0 - beta1 ** (i + 1))    
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        if i == 0:
            m[key] = np.zeros_like(network.params[key])
            v[key] = np.zeros_like(network.params[key])
            
        m[key] += (1 - beta1) * (grad[key] - m[key])
        v[key] += (1 - beta2) * (grad[key] ** 2 - v[key])            
        network.params[key] -= learning_rate_t * m[key] / (np.sqrt(v[key]) + 1e-7)                
        
        
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)        
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
                

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.09
#                 : 10. 正答率(テスト) = 0.1071
# Generation: 20. 正答率(トレーニング) = 0.11
#                 : 20. 正答率(テスト) = 0.1256
# Generation: 30. 正答率(トレーニング) = 0.19
#                 : 30. 正答率(テスト) = 0.227
# Generation: 40. 正答率(トレーニング) = 0.17
#                 : 40. 正答率(テスト) = 0.213
# Generation: 50. 正答率(トレーニング) = 0.13
#                 : 50. 正答率(テスト) = 0.227
# Generation: 60. 正答率(トレーニング) = 0.27
#                 : 60. 正答率(テスト) = 0.2229
# Generation: 70. 正答率(トレーニング) = 0.22
#                 : 70. 正答率(テスト) = 0.2026
# Generation: 80. 正答率(トレーニング) = 0.3
#                 : 80. 正答率(テスト) = 0.2255
# Generation: 90. 正答率(トレーニング) = 0.25
#                 : 90. 正答率(テスト) = 0.2951
# Generation: 100. 正答率(トレーニング) = 0.33
#                 : 100. 正答率(テスト) = 0.3572
# Generation: 110. 正答率(トレーニング) = 0.39
#                 : 110. 正答率(テスト) = 0.3624
# Generation: 120. 正答率(トレーニング) = 0.37
#                 : 120. 正答率(テスト) = 0.3766
# Generation: 130. 正答率(トレーニング) = 0.44
#                 : 130. 正答率(テスト) = 0.4348
# Generation: 140. 正答率(トレーニング) = 0.43
#                 : 140. 正答率(テスト) = 0.4453
# Generation: 150. 正答率(トレーニング) = 0.4
#                 : 150. 正答率(テスト) = 0.459
# Generation: 160. 正答率(トレーニング) = 0.45
#                 : 160. 正答率(テスト) = 0.4916
# Generation: 170. 正答率(トレーニング) = 0.49
#                 : 170. 正答率(テスト) = 0.4939
# Generation: 180. 正答率(トレーニング) = 0.58
#                 : 180. 正答率(テスト) = 0.502
# Generation: 190. 正答率(トレーニング) = 0.47
#                 : 190. 正答率(テスト) = 0.5337
# Generation: 200. 正答率(トレーニング) = 0.73
#                 : 200. 正答率(テスト) = 0.6256
# Generation: 210. 正答率(トレーニング) = 0.61
#                 : 210. 正答率(テスト) = 0.6407
# Generation: 220. 正答率(トレーニング) = 0.6
#                 : 220. 正答率(テスト) = 0.6569
# Generation: 230. 正答率(トレーニング) = 0.73
#                 : 230. 正答率(テスト) = 0.7083
# Generation: 240. 正答率(トレーニング) = 0.66
#                 : 240. 正答率(テスト) = 0.7047
# Generation: 250. 正答率(トレーニング) = 0.8
#                 : 250. 正答率(テスト) = 0.775
# Generation: 260. 正答率(トレーニング) = 0.79
#                 : 260. 正答率(テスト) = 0.7792
# Generation: 270. 正答率(トレーニング) = 0.73
#                 : 270. 正答率(テスト) = 0.8037
# Generation: 280. 正答率(トレーニング) = 0.8
#                 : 280. 正答率(テスト) = 0.837
# Generation: 290. 正答率(トレーニング) = 0.89
#                 : 290. 正答率(テスト) = 0.867
# Generation: 300. 正答率(トレーニング) = 0.89
#                 : 300. 正答率(テスト) = 0.8811
# Generation: 310. 正答率(トレーニング) = 0.99
#                 : 310. 正答率(テスト) = 0.8833
# Generation: 320. 正答率(トレーニング) = 0.93
#                 : 320. 正答率(テスト) = 0.8984
# Generation: 330. 正答率(トレーニング) = 0.94
#                 : 330. 正答率(テスト) = 0.901
# Generation: 340. 正答率(トレーニング) = 0.97
#                 : 340. 正答率(テスト) = 0.908
# Generation: 350. 正答率(トレーニング) = 0.96
#                 : 350. 正答率(テスト) = 0.9064
# Generation: 360. 正答率(トレーニング) = 0.94
#                 : 360. 正答率(テスト) = 0.9136
# Generation: 370. 正答率(トレーニング) = 0.87
#                 : 370. 正答率(テスト) = 0.9151
# Generation: 380. 正答率(トレーニング) = 0.95
#                 : 380. 正答率(テスト) = 0.9158
# Generation: 390. 正答率(トレーニング) = 0.92
#                 : 390. 正答率(テスト) = 0.9201
# Generation: 400. 正答率(トレーニング) = 0.92
#                 : 400. 正答率(テスト) = 0.9161
# Generation: 410. 正答率(トレーニング) = 0.96
#                 : 410. 正答率(テスト) = 0.9207
# Generation: 420. 正答率(トレーニング) = 0.92
#                 : 420. 正答率(テスト) = 0.92
# Generation: 430. 正答率(トレーニング) = 0.98
#                 : 430. 正答率(テスト) = 0.923
# Generation: 440. 正答率(トレーニング) = 0.93
#                 : 440. 正答率(テスト) = 0.9233
# Generation: 450. 正答率(トレーニング) = 0.87
#                 : 450. 正答率(テスト) = 0.9222
# Generation: 460. 正答率(トレーニング) = 0.95
#                 : 460. 正答率(テスト) = 0.9265
# Generation: 470. 正答率(トレーニング) = 0.93
#                 : 470. 正答率(テスト) = 0.9215
# Generation: 480. 正答率(トレーニング) = 0.96
#                 : 480. 正答率(テスト) = 0.9295
# Generation: 490. 正答率(トレーニング) = 0.96
#                 : 490. 正答率(テスト) = 0.9273
# Generation: 500. 正答率(トレーニング) = 0.93
#                 : 500. 正答率(テスト) = 0.9293
# Generation: 510. 正答率(トレーニング) = 0.93
#                 : 510. 正答率(テスト) = 0.932
# Generation: 520. 正答率(トレーニング) = 0.93
#                 : 520. 正答率(テスト) = 0.9251
# Generation: 530. 正答率(トレーニング) = 0.93
#                 : 530. 正答率(テスト) = 0.9227
# Generation: 540. 正答率(トレーニング) = 0.9
#                 : 540. 正答率(テスト) = 0.9276
# Generation: 550. 正答率(トレーニング) = 0.9
#                 : 550. 正答率(テスト) = 0.934
# Generation: 560. 正答率(トレーニング) = 0.96
#                 : 560. 正答率(テスト) = 0.9307
# Generation: 570. 正答率(トレーニング) = 0.96
#                 : 570. 正答率(テスト) = 0.9335
# Generation: 580. 正答率(トレーニング) = 0.99
#                 : 580. 正答率(テスト) = 0.9341
# Generation: 590. 正答率(トレーニング) = 0.97
#                 : 590. 正答率(テスト) = 0.9343
# Generation: 600. 正答率(トレーニング) = 0.95
#                 : 600. 正答率(テスト) = 0.933
# Generation: 610. 正答率(トレーニング) = 0.96
#                 : 610. 正答率(テスト) = 0.9328
# Generation: 620. 正答率(トレーニング) = 0.92
#                 : 620. 正答率(テスト) = 0.9346
# Generation: 630. 正答率(トレーニング) = 0.93
#                 : 630. 正答率(テスト) = 0.9372
# Generation: 640. 正答率(トレーニング) = 0.96
#                 : 640. 正答率(テスト) = 0.9357
# Generation: 650. 正答率(トレーニング) = 0.95
#                 : 650. 正答率(テスト) = 0.9355
# Generation: 660. 正答率(トレーニング) = 0.93
#                 : 660. 正答率(テスト) = 0.9361
# Generation: 670. 正答率(トレーニング) = 0.96
#                 : 670. 正答率(テスト) = 0.9363
# Generation: 680. 正答率(トレーニング) = 0.96
#                 : 680. 正答率(テスト) = 0.939
# Generation: 690. 正答率(トレーニング) = 0.96
#                 : 690. 正答率(テスト) = 0.9408
# Generation: 700. 正答率(トレーニング) = 0.91
#                 : 700. 正答率(テスト) = 0.9408
# Generation: 710. 正答率(トレーニング) = 0.94
#                 : 710. 正答率(テスト) = 0.9371
# Generation: 720. 正答率(トレーニング) = 0.98
#                 : 720. 正答率(テスト) = 0.9357
# Generation: 730. 正答率(トレーニング) = 0.95
#                 : 730. 正答率(テスト) = 0.9365
# Generation: 740. 正答率(トレーニング) = 0.97
#                 : 740. 正答率(テスト) = 0.9456
# Generation: 750. 正答率(トレーニング) = 0.96
#                 : 750. 正答率(テスト) = 0.9434
# Generation: 760. 正答率(トレーニング) = 0.94
#                 : 760. 正答率(テスト) = 0.9408
# Generation: 770. 正答率(トレーニング) = 0.94
#                 : 770. 正答率(テスト) = 0.9402
# Generation: 780. 正答率(トレーニング) = 0.97
#                 : 780. 正答率(テスト) = 0.9393
# Generation: 790. 正答率(トレーニング) = 1.0
#                 : 790. 正答率(テスト) = 0.9424
# Generation: 800. 正答率(トレーニング) = 0.95
#                 : 800. 正答率(テスト) = 0.9461
# Generation: 810. 正答率(トレーニング) = 0.93
#                 : 810. 正答率(テスト) = 0.9431
# Generation: 820. 正答率(トレーニング) = 0.96
#                 : 820. 正答率(テスト) = 0.9417
# Generation: 830. 正答率(トレーニング) = 0.91
#                 : 830. 正答率(テスト) = 0.9414
# Generation: 840. 正答率(トレーニング) = 0.95
#                 : 840. 正答率(テスト) = 0.9432
# Generation: 850. 正答率(トレーニング) = 0.96
#                 : 850. 正答率(テスト) = 0.9444
# Generation: 860. 正答率(トレーニング) = 0.98
#                 : 860. 正答率(テスト) = 0.9436
# Generation: 870. 正答率(トレーニング) = 0.91
#                 : 870. 正答率(テスト) = 0.9459
# Generation: 880. 正答率(トレーニング) = 0.94
#                 : 880. 正答率(テスト) = 0.9398
# Generation: 890. 正答率(トレーニング) = 0.97
#                 : 890. 正答率(テスト) = 0.9473
# Generation: 900. 正答率(トレーニング) = 0.94
#                 : 900. 正答率(テスト) = 0.9436
# Generation: 910. 正答率(トレーニング) = 0.93
#                 : 910. 正答率(テスト) = 0.9438
# Generation: 920. 正答率(トレーニング) = 0.97
#                 : 920. 正答率(テスト) = 0.9474
# Generation: 930. 正答率(トレーニング) = 0.96
#                 : 930. 正答率(テスト) = 0.9429
# Generation: 940. 正答率(トレーニング) = 0.98
#                 : 940. 正答率(テスト) = 0.9434
# Generation: 950. 正答率(トレーニング) = 0.96
#                 : 950. 正答率(テスト) = 0.9428
# Generation: 960. 正答率(トレーニング) = 0.93
#                 : 960. 正答率(テスト) = 0.9399
# Generation: 970. 正答率(トレーニング) = 0.97
#                 : 970. 正答率(テスト) = 0.9386
# Generation: 980. 正答率(トレーニング) = 0.93
#                 : 980. 正答率(テスト) = 0.9438
# Generation: 990. 正答率(トレーニング) = 0.96
#                 : 990. 正答率(テスト) = 0.9465
# Generation: 1000. 正答率(トレーニング) = 0.97
#                 : 1000. 正答率(テスト) = 0.9401

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ## [try] 学習率を変えてみよう

# %% [markdown]
# ## [try] 活性化関数と重みの初期化方法を変えてみよう
# 初期状態ではsigmoid - gauss<br>
# activationはReLU、weight_init_stdは別の数値や'Xavier'・'He'に変更可能

# %% [markdown]
# ## [try] バッチ正規化をしてみよう
# use_batchnormをTrueにしよう
#
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
